# %% [markdown]
# <a href="https://colab.research.google.com/github/nikatnguyen/deep-learning-challenge/blob/main/AlphabetSoupCharity_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN', 'NAME', 'AFFILIATION'
df = application_df.drop(columns=['EIN','NAME', 'AFFILIATION'])
df.head()
# Out:
#   APPLICATION_TYPE CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0              T10          C1000    ProductDev   Association       1
# 1               T3          C2000  Preservation  Co-operative       1
# 2               T5          C3000    ProductDev   Association       1
# 3               T3          C2000  Preservation         Trust       1
# 4               T3          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_count = application_df['CLASSIFICATION'].value_counts()
classification_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
print(classification_count[classification_count > 1])
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_count[classification_count < 500].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(["IS_SUCCESSFUL"], axis='columns').values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X)
# Out:
# [[ 10520599         1      5000 ...         0         1         0]
#  [ 10531628         1    108590 ...         0         1         0]
#  [ 10547893         1      5000 ...         0         1         0]
#  ...
#  [996012607         1      5000 ...         0         1         0]
#  [996015768         1      5000 ...         0         1         0]
#  [996086871         1  36500179 ...         0         1         0]]

# %%
print(y)
# Out:
# [1 1 0 ... 0 1 0]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                1569120
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 20)                620
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 1572191 (6.00 MB)
# Trainable params: 1572191 (6.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 10s 11ms/step - loss: 0.4704 - accuracy: 0.7768
# Epoch 2/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.1510 - accuracy: 0.9431
# Epoch 3/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0996 - accuracy: 0.9613
# Epoch 4/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0941 - accuracy: 0.9621
# Epoch 5/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0924 - accuracy: 0.9621
# Epoch 6/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0912 - accuracy: 0.9621
# Epoch 7/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0910 - accuracy: 0.9628
# Epoch 8/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0903 - accuracy: 0.9628
# Epoch 9/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0900 - accuracy: 0.9631
# Epoch 10/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0888 - accuracy: 0.9632
# Epoch 11/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0887 - accuracy: 0.9632
# Epoch 12/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0877 - accuracy: 0.9634
# Epoch 13/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0875 - accuracy: 0.9636
# Epoch 14/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0876 - accuracy: 0.9638
# Epoch 15/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0869 - accuracy: 0.9642
# Epoch 16/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0866 - accuracy: 0.9644
# Epoch 17/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0863 - accuracy: 0.9643
# Epoch 18/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0858 - accuracy: 0.9649
# Epoch 19/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0854 - accuracy: 0.9645
# Epoch 20/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0852 - accuracy: 0.9650
# Epoch 21/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0850 - accuracy: 0.9645
# Epoch 22/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0843 - accuracy: 0.9657
# Epoch 23/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0844 - accuracy: 0.9653
# Epoch 24/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0838 - accuracy: 0.9652
# Epoch 25/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0836 - accuracy: 0.9656
# Epoch 26/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0834 - accuracy: 0.9654
# Epoch 27/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0825 - accuracy: 0.9662
# Epoch 28/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0827 - accuracy: 0.9659
# Epoch 29/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0816 - accuracy: 0.9661
# Epoch 30/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0821 - accuracy: 0.9659
# Epoch 31/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0816 - accuracy: 0.9663
# Epoch 32/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0813 - accuracy: 0.9663
# Epoch 33/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0809 - accuracy: 0.9663
# Epoch 34/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0806 - accuracy: 0.9667
# Epoch 35/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0798 - accuracy: 0.9669
# Epoch 36/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0800 - accuracy: 0.9675
# Epoch 37/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0794 - accuracy: 0.9668
# Epoch 38/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0796 - accuracy: 0.9675
# Epoch 39/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0788 - accuracy: 0.9679
# Epoch 40/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0789 - accuracy: 0.9676
# Epoch 41/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0784 - accuracy: 0.9674
# Epoch 42/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0776 - accuracy: 0.9678
# Epoch 43/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0775 - accuracy: 0.9686
# Epoch 44/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0772 - accuracy: 0.9681
# Epoch 45/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0768 - accuracy: 0.9685
# Epoch 46/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0767 - accuracy: 0.9685
# Epoch 47/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0763 - accuracy: 0.9687
# Epoch 48/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0762 - accuracy: 0.9687
# Epoch 49/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0762 - accuracy: 0.9687
# Epoch 50/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0758 - accuracy: 0.9682
# Epoch 51/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0751 - accuracy: 0.9682
# Epoch 52/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0751 - accuracy: 0.9692
# Epoch 53/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0747 - accuracy: 0.9693
# Epoch 54/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0739 - accuracy: 0.9700
# Epoch 55/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0741 - accuracy: 0.9694
# Epoch 56/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0741 - accuracy: 0.9701
# Epoch 57/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0738 - accuracy: 0.9694
# Epoch 58/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0736 - accuracy: 0.9698
# Epoch 59/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0736 - accuracy: 0.9703
# Epoch 60/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0730 - accuracy: 0.9699
# Epoch 61/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0728 - accuracy: 0.9702
# Epoch 62/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0732 - accuracy: 0.9702
# Epoch 63/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0730 - accuracy: 0.9700
# Epoch 64/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0730 - accuracy: 0.9702
# Epoch 65/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0722 - accuracy: 0.9701
# Epoch 66/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0718 - accuracy: 0.9702
# Epoch 67/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0720 - accuracy: 0.9700
# Epoch 68/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0717 - accuracy: 0.9701
# Epoch 69/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0717 - accuracy: 0.9702
# Epoch 70/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0715 - accuracy: 0.9705
# Epoch 71/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0728 - accuracy: 0.9706
# Epoch 72/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0716 - accuracy: 0.9704
# Epoch 73/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0708 - accuracy: 0.9705
# Epoch 74/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0710 - accuracy: 0.9708
# Epoch 75/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0708 - accuracy: 0.9709
# Epoch 76/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0708 - accuracy: 0.9707
# Epoch 77/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0708 - accuracy: 0.9703
# Epoch 78/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0705 - accuracy: 0.9708
# Epoch 79/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0704 - accuracy: 0.9708
# Epoch 80/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0702 - accuracy: 0.9709
# Epoch 81/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0705 - accuracy: 0.9706
# Epoch 82/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0705 - accuracy: 0.9709
# Epoch 83/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0697 - accuracy: 0.9711
# Epoch 84/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0695 - accuracy: 0.9711
# Epoch 85/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0696 - accuracy: 0.9710
# Epoch 86/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0700 - accuracy: 0.9703
# Epoch 87/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0692 - accuracy: 0.9708
# Epoch 88/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0694 - accuracy: 0.9712
# Epoch 89/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0687 - accuracy: 0.9714
# Epoch 90/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0690 - accuracy: 0.9710
# Epoch 91/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0692 - accuracy: 0.9715
# Epoch 92/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0690 - accuracy: 0.9718
# Epoch 93/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0691 - accuracy: 0.9714
# Epoch 94/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0687 - accuracy: 0.9717
# Epoch 95/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0681 - accuracy: 0.9717
# Epoch 96/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0685 - accuracy: 0.9717
# Epoch 97/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0683 - accuracy: 0.9711
# Epoch 98/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0682 - accuracy: 0.9712
# Epoch 99/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0684 - accuracy: 0.9719
# Epoch 100/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0680 - accuracy: 0.9715

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.8212 - accuracy: 0.7008 - 915ms/epoch - 3ms/step
# Loss: 0.8212448954582214, Accuracy: 0.7007580399513245

# %%
# Export our model to HDF5 file
nn.save_weights('AlphabetSoupCharity.h5')
