# %% [markdown]
# <a href="https://colab.research.google.com/github/nikatnguyen/deep-learning-challenge/blob/main/AlphabetSoupCharity_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN', 'NAME', 'AFFILIATION'
df = application_df.drop(columns=['EIN','NAME', 'AFFILIATION'])
df.head()
# Out:
#   APPLICATION_TYPE CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0              T10          C1000    ProductDev   Association       1
# 1               T3          C2000  Preservation  Co-operative       1
# 2               T5          C3000    ProductDev   Association       1
# 3               T3          C2000  Preservation         Trust       1
# 4               T3          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_count = application_df['CLASSIFICATION'].value_counts()
classification_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
print(classification_count[classification_count > 1])
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_count[classification_count < 500].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(["IS_SUCCESSFUL"], axis='columns').values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X)
# Out:
# [[ 10520599         1      5000 ...         0         1         0]
#  [ 10531628         1    108590 ...         0         1         0]
#  [ 10547893         1      5000 ...         0         1         0]
#  ...
#  [996012607         1      5000 ...         0         1         0]
#  [996015768         1      5000 ...         0         1         0]
#  [996086871         1  36500179 ...         0         1         0]]

# %%
print(y)
# Out:
# [1 1 0 ... 0 1 0]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 20
hidden_nodes_layer4 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                1569120
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 20)                620
#
#  dense_3 (Dense)             (None, 10)                210
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1572391 (6.00 MB)
# Trainable params: 1572391 (6.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 10s 11ms/step - loss: 0.4774 - accuracy: 0.7715
# Epoch 2/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.1946 - accuracy: 0.9211
# Epoch 3/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0995 - accuracy: 0.9609
# Epoch 4/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0938 - accuracy: 0.9619
# Epoch 5/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0924 - accuracy: 0.9624
# Epoch 6/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0918 - accuracy: 0.9629
# Epoch 7/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0905 - accuracy: 0.9628
# Epoch 8/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0899 - accuracy: 0.9626
# Epoch 9/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0897 - accuracy: 0.9636
# Epoch 10/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0887 - accuracy: 0.9626
# Epoch 11/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0887 - accuracy: 0.9633
# Epoch 12/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0881 - accuracy: 0.9640
# Epoch 13/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0883 - accuracy: 0.9638
# Epoch 14/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0872 - accuracy: 0.9642
# Epoch 15/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0871 - accuracy: 0.9642
# Epoch 16/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0867 - accuracy: 0.9637
# Epoch 17/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0862 - accuracy: 0.9640
# Epoch 18/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0861 - accuracy: 0.9642
# Epoch 19/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0856 - accuracy: 0.9643
# Epoch 20/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0859 - accuracy: 0.9644
# Epoch 21/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0849 - accuracy: 0.9649
# Epoch 22/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0844 - accuracy: 0.9655
# Epoch 23/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0843 - accuracy: 0.9645
# Epoch 24/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0842 - accuracy: 0.9652
# Epoch 25/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0839 - accuracy: 0.9654
# Epoch 26/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0833 - accuracy: 0.9656
# Epoch 27/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0829 - accuracy: 0.9663
# Epoch 28/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0824 - accuracy: 0.9659
# Epoch 29/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0823 - accuracy: 0.9663
# Epoch 30/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.0821 - accuracy: 0.9663
# Epoch 31/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0816 - accuracy: 0.9671
# Epoch 32/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0814 - accuracy: 0.9665
# Epoch 33/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0812 - accuracy: 0.9665
# Epoch 34/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0807 - accuracy: 0.9669
# Epoch 35/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0808 - accuracy: 0.9670
# Epoch 36/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0803 - accuracy: 0.9670
# Epoch 37/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0800 - accuracy: 0.9670
# Epoch 38/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0802 - accuracy: 0.9665
# Epoch 39/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0793 - accuracy: 0.9672
# Epoch 40/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0797 - accuracy: 0.9669
# Epoch 41/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0794 - accuracy: 0.9671
# Epoch 42/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0792 - accuracy: 0.9668
# Epoch 43/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0787 - accuracy: 0.9672
# Epoch 44/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0781 - accuracy: 0.9679
# Epoch 45/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0782 - accuracy: 0.9677
# Epoch 46/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0780 - accuracy: 0.9677
# Epoch 47/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0782 - accuracy: 0.9675
# Epoch 48/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0771 - accuracy: 0.9680
# Epoch 49/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0772 - accuracy: 0.9685
# Epoch 50/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0782 - accuracy: 0.9680
# Epoch 51/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0769 - accuracy: 0.9679
# Epoch 52/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0761 - accuracy: 0.9681
# Epoch 53/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0764 - accuracy: 0.9686
# Epoch 54/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0758 - accuracy: 0.9684
# Epoch 55/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0757 - accuracy: 0.9689
# Epoch 56/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0755 - accuracy: 0.9692
# Epoch 57/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0754 - accuracy: 0.9693
# Epoch 58/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0753 - accuracy: 0.9691
# Epoch 59/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0749 - accuracy: 0.9691
# Epoch 60/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0749 - accuracy: 0.9696
# Epoch 61/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0743 - accuracy: 0.9696
# Epoch 62/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0749 - accuracy: 0.9694
# Epoch 63/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0737 - accuracy: 0.9695
# Epoch 64/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0739 - accuracy: 0.9695
# Epoch 65/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0737 - accuracy: 0.9694
# Epoch 66/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0737 - accuracy: 0.9692
# Epoch 67/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0733 - accuracy: 0.9703
# Epoch 68/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0737 - accuracy: 0.9697
# Epoch 69/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0731 - accuracy: 0.9703
# Epoch 70/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0736 - accuracy: 0.9702
# Epoch 71/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0725 - accuracy: 0.9708
# Epoch 72/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0720 - accuracy: 0.9708
# Epoch 73/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0721 - accuracy: 0.9701
# Epoch 74/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0716 - accuracy: 0.9709
# Epoch 75/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0725 - accuracy: 0.9705
# Epoch 76/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0717 - accuracy: 0.9703
# Epoch 77/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0719 - accuracy: 0.9706
# Epoch 78/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0711 - accuracy: 0.9714
# Epoch 79/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0735 - accuracy: 0.9702
# Epoch 80/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0713 - accuracy: 0.9710
# Epoch 81/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0708 - accuracy: 0.9716
# Epoch 82/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0706 - accuracy: 0.9714
# Epoch 83/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0713 - accuracy: 0.9706
# Epoch 84/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0703 - accuracy: 0.9712
# Epoch 85/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0709 - accuracy: 0.9712
# Epoch 86/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0709 - accuracy: 0.9712
# Epoch 87/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0704 - accuracy: 0.9710
# Epoch 88/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0704 - accuracy: 0.9704
# Epoch 89/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0706 - accuracy: 0.9704
# Epoch 90/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0699 - accuracy: 0.9710
# Epoch 91/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0701 - accuracy: 0.9706
# Epoch 92/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0696 - accuracy: 0.9715
# Epoch 93/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0724 - accuracy: 0.9706
# Epoch 94/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0706 - accuracy: 0.9711
# Epoch 95/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0694 - accuracy: 0.9713
# Epoch 96/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0689 - accuracy: 0.9719
# Epoch 97/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0691 - accuracy: 0.9710
# Epoch 98/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0694 - accuracy: 0.9716
# Epoch 99/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0689 - accuracy: 0.9717
# Epoch 100/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0694 - accuracy: 0.9708

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.9111 - accuracy: 0.7012 - 1s/epoch - 4ms/step
# Loss: 0.9111442565917969, Accuracy: 0.7012245059013367

# %% [markdown]
# ATTEMPT 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  100

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 100)               1961400
#
#  dense_6 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 1961501 (7.48 MB)
# Trainable params: 1961501 (7.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn2.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 10s 12ms/step - loss: 1.0662 - accuracy: 0.6630
# Epoch 2/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.4738 - accuracy: 0.9021
# Epoch 3/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.1641 - accuracy: 0.9562
# Epoch 4/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.1334 - accuracy: 0.9598
# Epoch 5/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.1196 - accuracy: 0.9609
# Epoch 6/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.1122 - accuracy: 0.9614
# Epoch 7/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.1079 - accuracy: 0.9617
# Epoch 8/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.1047 - accuracy: 0.9618
# Epoch 9/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.1029 - accuracy: 0.9624
# Epoch 10/100
# 804/804 [==============================] - 21s 26ms/step - loss: 0.1017 - accuracy: 0.9617
# Epoch 11/100
# 804/804 [==============================] - 16s 20ms/step - loss: 0.1008 - accuracy: 0.9618
# Epoch 12/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0997 - accuracy: 0.9626
# Epoch 13/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0990 - accuracy: 0.9621
# Epoch 14/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0988 - accuracy: 0.9624
# Epoch 15/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0974 - accuracy: 0.9626
# Epoch 16/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0969 - accuracy: 0.9630
# Epoch 17/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0959 - accuracy: 0.9628
# Epoch 18/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0954 - accuracy: 0.9630
# Epoch 19/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0948 - accuracy: 0.9632
# Epoch 20/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0941 - accuracy: 0.9628
# Epoch 21/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0936 - accuracy: 0.9629
# Epoch 22/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0929 - accuracy: 0.9632
# Epoch 23/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0922 - accuracy: 0.9632
# Epoch 24/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0916 - accuracy: 0.9636
# Epoch 25/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0908 - accuracy: 0.9637
# Epoch 26/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0902 - accuracy: 0.9636
# Epoch 27/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0895 - accuracy: 0.9646
# Epoch 28/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0891 - accuracy: 0.9640
# Epoch 29/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0884 - accuracy: 0.9649
# Epoch 30/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0879 - accuracy: 0.9648
# Epoch 31/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0872 - accuracy: 0.9649
# Epoch 32/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0869 - accuracy: 0.9648
# Epoch 33/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0864 - accuracy: 0.9651
# Epoch 34/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0860 - accuracy: 0.9652
# Epoch 35/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0858 - accuracy: 0.9658
# Epoch 36/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0855 - accuracy: 0.9654
# Epoch 37/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0848 - accuracy: 0.9660
# Epoch 38/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0843 - accuracy: 0.9656
# Epoch 39/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0839 - accuracy: 0.9661
# Epoch 40/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0840 - accuracy: 0.9663
# Epoch 41/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0831 - accuracy: 0.9666
# Epoch 42/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0831 - accuracy: 0.9664
# Epoch 43/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0829 - accuracy: 0.9666
# Epoch 44/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0825 - accuracy: 0.9667
# Epoch 45/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0823 - accuracy: 0.9671
# Epoch 46/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0814 - accuracy: 0.9677
# Epoch 47/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0817 - accuracy: 0.9665
# Epoch 48/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0814 - accuracy: 0.9674
# Epoch 49/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0809 - accuracy: 0.9676
# Epoch 50/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0806 - accuracy: 0.9679
# Epoch 51/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0806 - accuracy: 0.9677
# Epoch 52/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0803 - accuracy: 0.9674
# Epoch 53/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0803 - accuracy: 0.9676
# Epoch 54/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0805 - accuracy: 0.9677
# Epoch 55/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0799 - accuracy: 0.9681
# Epoch 56/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0794 - accuracy: 0.9681
# Epoch 57/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0797 - accuracy: 0.9675
# Epoch 58/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0792 - accuracy: 0.9680
# Epoch 59/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0792 - accuracy: 0.9681
# Epoch 60/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0794 - accuracy: 0.9678
# Epoch 61/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0789 - accuracy: 0.9686
# Epoch 62/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0785 - accuracy: 0.9686
# Epoch 63/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0785 - accuracy: 0.9682
# Epoch 64/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0781 - accuracy: 0.9685
# Epoch 65/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0780 - accuracy: 0.9686
# Epoch 66/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0783 - accuracy: 0.9681
# Epoch 67/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0779 - accuracy: 0.9689
# Epoch 68/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0776 - accuracy: 0.9686
# Epoch 69/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0776 - accuracy: 0.9687
# Epoch 70/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.0775 - accuracy: 0.9686
# Epoch 71/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0771 - accuracy: 0.9688
# Epoch 72/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0771 - accuracy: 0.9687
# Epoch 73/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0774 - accuracy: 0.9686
# Epoch 74/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0769 - accuracy: 0.9687
# Epoch 75/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0769 - accuracy: 0.9689
# Epoch 76/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0771 - accuracy: 0.9687
# Epoch 77/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0768 - accuracy: 0.9687
# Epoch 78/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0769 - accuracy: 0.9690
# Epoch 79/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0768 - accuracy: 0.9688
# Epoch 80/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0764 - accuracy: 0.9689
# Epoch 81/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0764 - accuracy: 0.9689
# Epoch 82/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0763 - accuracy: 0.9689
# Epoch 83/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0764 - accuracy: 0.9693
# Epoch 84/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.0761 - accuracy: 0.9687
# Epoch 85/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0762 - accuracy: 0.9693
# Epoch 86/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0759 - accuracy: 0.9691
# Epoch 87/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0762 - accuracy: 0.9693
# Epoch 88/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0759 - accuracy: 0.9692
# Epoch 89/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0757 - accuracy: 0.9696
# Epoch 90/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0757 - accuracy: 0.9695
# Epoch 91/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.0759 - accuracy: 0.9697
# Epoch 92/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0756 - accuracy: 0.9694
# Epoch 93/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0756 - accuracy: 0.9696
# Epoch 94/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0755 - accuracy: 0.9694
# Epoch 95/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0755 - accuracy: 0.9693
# Epoch 96/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0758 - accuracy: 0.9691
# Epoch 97/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0753 - accuracy: 0.9691
# Epoch 98/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0752 - accuracy: 0.9691
# Epoch 99/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0752 - accuracy: 0.9696
# Epoch 100/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0754 - accuracy: 0.9694

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 1.0130 - accuracy: 0.7212 - 1s/epoch - 4ms/step
# Loss: 1.0129706859588623, Accuracy: 0.72116619348526

# %% [markdown]
# ATTEMPT 3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 20

nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 80)                1569120
#
#  dense_8 (Dense)             (None, 30)                2430
#
#  dense_9 (Dense)             (None, 20)                620
#
#  dense_10 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 1572191 (6.00 MB)
# Trainable params: 1572191 (6.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn3.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 10s 11ms/step - loss: 0.4760 - accuracy: 0.7724
# Epoch 2/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.1237 - accuracy: 0.9550
# Epoch 3/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0975 - accuracy: 0.9618
# Epoch 4/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0936 - accuracy: 0.9621
# Epoch 5/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0924 - accuracy: 0.9618
# Epoch 6/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0925 - accuracy: 0.9624
# Epoch 7/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0908 - accuracy: 0.9623
# Epoch 8/100
# 804/804 [==============================] - 10s 12ms/step - loss: 0.0906 - accuracy: 0.9624
# Epoch 9/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0901 - accuracy: 0.9632
# Epoch 10/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0890 - accuracy: 0.9628
# Epoch 11/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0892 - accuracy: 0.9627
# Epoch 12/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0885 - accuracy: 0.9631
# Epoch 13/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0878 - accuracy: 0.9634
# Epoch 14/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0876 - accuracy: 0.9638
# Epoch 15/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0871 - accuracy: 0.9641
# Epoch 16/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0866 - accuracy: 0.9638
# Epoch 17/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0863 - accuracy: 0.9638
# Epoch 18/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0859 - accuracy: 0.9638
# Epoch 19/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0854 - accuracy: 0.9642
# Epoch 20/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0850 - accuracy: 0.9647
# Epoch 21/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0853 - accuracy: 0.9642
# Epoch 22/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0839 - accuracy: 0.9647
# Epoch 23/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0843 - accuracy: 0.9644
# Epoch 24/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0841 - accuracy: 0.9646
# Epoch 25/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0841 - accuracy: 0.9647
# Epoch 26/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0837 - accuracy: 0.9645
# Epoch 27/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0833 - accuracy: 0.9654
# Epoch 28/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0824 - accuracy: 0.9656
# Epoch 29/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0823 - accuracy: 0.9659
# Epoch 30/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0820 - accuracy: 0.9655
# Epoch 31/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0820 - accuracy: 0.9664
# Epoch 32/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0813 - accuracy: 0.9661
# Epoch 33/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0813 - accuracy: 0.9661
# Epoch 34/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0810 - accuracy: 0.9660
# Epoch 35/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0805 - accuracy: 0.9668
# Epoch 36/100
# 804/804 [==============================] - 10s 13ms/step - loss: 0.0801 - accuracy: 0.9671
# Epoch 37/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0800 - accuracy: 0.9667
# Epoch 38/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0796 - accuracy: 0.9673
# Epoch 39/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0792 - accuracy: 0.9676
# Epoch 40/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0788 - accuracy: 0.9668
# Epoch 41/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0789 - accuracy: 0.9671
# Epoch 42/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0783 - accuracy: 0.9674
# Epoch 43/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0778 - accuracy: 0.9681
# Epoch 44/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0777 - accuracy: 0.9684
# Epoch 45/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0782 - accuracy: 0.9680
# Epoch 46/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0773 - accuracy: 0.9680
# Epoch 47/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0771 - accuracy: 0.9680
# Epoch 48/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0766 - accuracy: 0.9679
# Epoch 49/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0763 - accuracy: 0.9689
# Epoch 50/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0763 - accuracy: 0.9687
# Epoch 51/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0764 - accuracy: 0.9686
# Epoch 52/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0759 - accuracy: 0.9691
# Epoch 53/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0753 - accuracy: 0.9692
# Epoch 54/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0751 - accuracy: 0.9689
# Epoch 55/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0756 - accuracy: 0.9688
# Epoch 56/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0749 - accuracy: 0.9696
# Epoch 57/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0753 - accuracy: 0.9689
# Epoch 58/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0746 - accuracy: 0.9689
# Epoch 59/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0746 - accuracy: 0.9698
# Epoch 60/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0742 - accuracy: 0.9691
# Epoch 61/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0740 - accuracy: 0.9696
# Epoch 62/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0734 - accuracy: 0.9696
# Epoch 63/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0737 - accuracy: 0.9699
# Epoch 64/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0736 - accuracy: 0.9696
# Epoch 65/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0734 - accuracy: 0.9698
# Epoch 66/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0737 - accuracy: 0.9696
# Epoch 67/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0732 - accuracy: 0.9696
# Epoch 68/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0729 - accuracy: 0.9698
# Epoch 69/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0729 - accuracy: 0.9697
# Epoch 70/100
# 804/804 [==============================] - 8s 11ms/step - loss: 0.0725 - accuracy: 0.9702
# Epoch 71/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0724 - accuracy: 0.9699
# Epoch 72/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0728 - accuracy: 0.9697
# Epoch 73/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0730 - accuracy: 0.9701
# Epoch 74/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0717 - accuracy: 0.9710
# Epoch 75/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0720 - accuracy: 0.9701
# Epoch 76/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0715 - accuracy: 0.9706
# Epoch 77/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0738 - accuracy: 0.9698
# Epoch 78/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0712 - accuracy: 0.9705
# Epoch 79/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0711 - accuracy: 0.9700
# Epoch 80/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0712 - accuracy: 0.9705
# Epoch 81/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0711 - accuracy: 0.9710
# Epoch 82/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0710 - accuracy: 0.9709
# Epoch 83/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0712 - accuracy: 0.9701
# Epoch 84/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0707 - accuracy: 0.9712
# Epoch 85/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0710 - accuracy: 0.9706
# Epoch 86/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0706 - accuracy: 0.9709
# Epoch 87/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0706 - accuracy: 0.9705
# Epoch 88/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0702 - accuracy: 0.9709
# Epoch 89/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0711 - accuracy: 0.9707
# Epoch 90/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0700 - accuracy: 0.9710
# Epoch 91/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0699 - accuracy: 0.9708
# Epoch 92/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0698 - accuracy: 0.9709
# Epoch 93/100
# 804/804 [==============================] - 9s 12ms/step - loss: 0.0693 - accuracy: 0.9712
# Epoch 94/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0693 - accuracy: 0.9713
# Epoch 95/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0696 - accuracy: 0.9712
# Epoch 96/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0691 - accuracy: 0.9711
# Epoch 97/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0697 - accuracy: 0.9709
# Epoch 98/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0696 - accuracy: 0.9716
# Epoch 99/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.0694 - accuracy: 0.9710
# Epoch 100/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0698 - accuracy: 0.9709

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.8965 - accuracy: 0.6331 - 827ms/epoch - 3ms/step
# Loss: 0.8964827656745911, Accuracy: 0.633119523525238

# %%
# Export our model to HDF5 file
nn.save_weights('AlphabetSoupCharity.h5')
nn2.save_weights('AlphabetSoupCharity2.h5')
nn2.save_weights('AlphabetSoupCharity3.h5')
